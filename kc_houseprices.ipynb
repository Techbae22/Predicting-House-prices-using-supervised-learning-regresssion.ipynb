# %% [markdown]
# <a href="https://colab.research.google.com/github/Techbae22/kc-houseprices.ipynb/blob/main/kc_houseprices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Preprocessing Phase**
#
# importing libraries

# %%
import pandas as pd

# %% [markdown]
# **Importing the Dataset**

# %%
df=pd.read_csv("kc_house_data.csv", delimiter= ",")

# %% [markdown]
# **Show the head of the dataset**

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# **Here we proceed to show some general information about the dataset**

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# We note that the dataset has 21,613 observations and 21 features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# Furthere more, we noted the below:
#
#
#
# *   "date" variable should be changed to a DateTime object
# *   "bathrooms" variable should be an integer

# %% [markdown]
# **Finding missing Values**
#
# Finding missing values position

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# The isnull() function indicates the position of the missing values. From this portion of the dataset, we note that there are no missing values, however we still need to have a deeper look at the entire dataset.

# %% [markdown]
# **Finding the number of Missing values on each column**

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Isnull().sum() function gives a summary of the number of missing values on each column. We can finally conclude that there are no missing values on this dataset

# %% [markdown]
# **Round float the "Bathrooms" variable to integer values**

# %%
import numpy as np

# %%
df["bathrooms"]=np.round(df["bathrooms"])

# %% [markdown]
# **Change "date" variable to DateTime object**

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# **Investigating the "bedrooms" variable for typos**

# %%
df["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# The house with 33 bedrooms is worth exploring further.

# %%
df[df['bedrooms'] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000.0        33        2.0         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15870      6000     1.0           0     0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15870            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15870           1330        4700
#
# [1 rows x 21 columns]

# %% [markdown]
# With only 2 bathrooms and a price of 640,000, it is very likely that this house is a 3 bedrooms house and 33 bedrooms as indicated in the dataset.

# %% [markdown]
# **Fix typo for "bedrooms" variable**

# %%
df.loc[15870, 'bedrooms'] = 3

# %%
df["bedrooms"].value_counts()
# Out:
# 3     9825
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# **Visualization Phase**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Distribution of the most important features**
#
#
# **Feature Distribution for "bedrooms"**

# %%
plt.title("Histogram of Different Number of Bedrooms")
plt.xlabel("Number of Bedrooms")
df["bedrooms"].plot.hist()

# %% [markdown]
# The majority of houses have 3 bedrooms.

# %% [markdown]
# **Feature Distribution for "bathrooms"**

# %%
plt.title("Histogram of Different Number of Bathrooms")
plt.xlabel("Number of Bathrooms")
df["bathrooms"].plot.hist()

# %% [markdown]
# Majority of houses have 2 bathrooms

# %% [markdown]
# **Feature Distribution for "floors"**

# %%
plt.title("Histogram of Different Number of Floors")
plt.xlabel("Number of Floors")
df["floors"].plot.hist()

# %% [markdown]
# from the histogram, we can tell that the majority of houses have 1 floor.

# %% [markdown]
# **Feature Distribution for "sqft_living"**

# %%
plt.title ("Histogram of Different Square Footage of the Living Space")
plt.xlabel("Square Footage of the Living Space")
df["sqft_living"].plot.hist()

# %% [markdown]
# From the histogram we note that most houses have living spaces of between 2000sq - 3000sq footage

# %% [markdown]
# **Feature Distribution for "sqft above"**

# %%
plt.title ("Histogram of Different Square Footage of the House apart from basement")
plt.xlabel("Square Footage of the House apart from basement")
df["sqft_above"].plot.hist()

# %% [markdown]
# The majority of houses are between 1500 and 2000 sqft above the basement.

# %% [markdown]
# **Distribution of the Target Value "Price"**

# %%
sns.distplot(df["price"], bins=50, hist=True, kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The prices for most of the houses' is approximately 500,000, but we can also notice that there are some outliers over 2 million.

# %% [markdown]
# **Correlation between "bedrooms" and "price"**

# %%
sns.boxplot(x= "bedrooms", y="price", data=df)

# %% [markdown]
# It is very obvious that as the number of "bathrooms" increase, so does the price of the house.

# %% [markdown]
# **Correlation between "floors" and "price"**

# %%
sns.boxplot(x= "floors", y="price", data=df)

# %% [markdown]
# As the number of "floors" increase (up to 2.5 floors), so does the price of houses. However, we noticed that a house with 3 or 3.5 floors has a lower median price.

# %% [markdown]
# **Correlation between "grade" and "price"**

# %%
sns.boxplot(x= "grade", y="price", data=df)

# %% [markdown]
# The "grade" variable seems to be a good predictor of price. The median house price increases with grade indicating that these features are positively correlated.

# %% [markdown]
# **Correlation Heatmap**

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 30 , 20 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }
        
    )

plot_correlation_map(df)

# %% [markdown]
# * square footage of the living space of a house ("sqft_living" variable) seems to be highly positively correlated with our target "price". Their correlation is equal to 0.7
#
# * Other features such as "bathrooms", "grade", "sqft_above", and "sqft_living15" seem to be moderately positively correlated with our target "price".

# %% [markdown]
# We can deduce from the heatmap that the most important features are the ones that are more correlated with the "price" variable. These features are "sqft_living", "bathrooms", "grade", "sqft_above", "sqft_living15", "view", "lat", "bedrooms", "sqft_basement", and "waterfront".

# %% [markdown]
# **Drop useless Columns**

# %%
new_data= df.copy()
new_data= new_data.drop(["id", "date"], axis=1)
new_data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
# 1  538000.0         3        2.0         2570      7242     2.0           0
# 2  180000.0         2        1.0          770     10000     1.0           0
# 3  604000.0         4        3.0         1960      5000     1.0           0
# 4  510000.0         3        2.0         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %% [markdown]
# **Supervised Learning: Regression Models**

# %% [markdown]
# Importing Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %% [markdown]
# **Splitting dataset into train and test sets**

# %%
X= new_data["sqft_living"].values[:,np.newaxis]
y= new_data["price"].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.35,random_state=40)

# %% [markdown]
# We have gone ahead to split our dataset into train and test set. We decided to work with the "sqft_living" as a single input variable for our Linear Regression model because we assessed it to be a good predictor based on its high correlation with our target "price". First, we seperated the feature "sqft_living" from target "price" and then we used the sklearn's train_test_split() function. We decided to keep 35% of our data for final testing of our model.

# %% [markdown]
# **Apply Linear Regresstion to the train set**

# %%
model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Let's test the model's performance**

# %%
predicted=model.predict(X_test)

# %% [markdown]
# **Plot the Linear Regression**

# %%
plt.scatter(X,y,color="r")
plt.title("Linear Regression")
plt.ylabel("Price")
plt.xlabel("Square Foot of the Living Space")
plt.plot(X,model.predict(X),color="k")
plt.show()

# %% [markdown]
# We observed that for smaller living areas, our model looks decent. However, as the "sqft_living" value increases, our model's performance declines, signifiying that "sqft_living" is not a good enough predictor for larger houses. It also makes sense because we do not have many houses with a large square footage for living spaces.

# %% [markdown]
# **Performance of the Linear Regression**

# %%
print("MSE: ", mean_squared_error(y_test,predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  62902408306.86502
# R squared:  0.4996528488387417

# %% [markdown]
# As one might expect, using a single feature did not provide a strong model because it is logically not enough since there are more than one important input to predict the price of a house.
#
# * MSE determines the average of the squared prediction error. MSE is equal to 62,902,408,306.86, which means that on an average, the actual price will be USD 62,902,408,306.86 more or less than our predicted price.
#
# * The R squared metric indicates that nearly 50% of the output variation can be explained by our model's inputs.

# %% [markdown]
# **Apply Multi-Linear Regression**

# %%
X=new_data[["sqft_living","grade", "bathrooms","sqft_above","view","bedrooms", "waterfront", "lat"]] #we have more than one input
y=new_data["price"].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(X_train,y_train) #fitting the training data
predicted=model.predict(X_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 42395401526.366455
# R squared 0.6627725559795452

# %% [markdown]
# Compared to linear regression, our model's accuracy has improved considerably well using multi-linear regression.
#
# * The MSE reduced compared to linear regression and is now equal to 42,395,401,526.36, which means that on average the actual price will be USD 42,395,401,526.36 more or less than our predicted price.
#
# * The R squared metric increased indicating that nearly 66.28% of the output variation can be explained by our model's inputs.

# %% [markdown]
# **Apply Polynomial Regression**

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
X= new_data[["sqft_living", "grade", "view", "waterfront", "sqft_above", "lat", "zipcode", "condition", "yr_built", "long"]]
y= new_data["price"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

X_train_fit = poly.fit_transform(X_train) #transforming our input data
lg.fit(X_train_fit, y_train)
X_test_ = poly.fit_transform(X_test)
predicted = lg.predict(X_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  24592914394.82578
# R squared:  0.804379593923102

# %% [markdown]
# Compared to linear regression and multi-linear regression, our model's accuracy has improved considerably using polynomial regression. Our model can be now considered a good one.
#
# * The MSE has reduced compared to linear regression and multi-linear regression and is now equal to 24,592,914,394.82, which means that on average the actual price will be USD 24,592,914,394.82 more or less than our predicted price.
#
# *  The R squared metric increased indicating that 80.44% of the output variation can be explained by our model's inputs.
